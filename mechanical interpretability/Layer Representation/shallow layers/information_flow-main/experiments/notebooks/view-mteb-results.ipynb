# %%
import logging
from typing import Any, Callable, List, Literal, Type, Dict, Union
from pathlib import Path
import argparse
import glob
import pickle
import os
import json
import mteb

import numpy as np
import torch
import mteb

from utils.misc.model_dataloader_utils import get_model_path, model_name_to_sizes
from utils.model_definitions.mteb_automodel_wrapper import AutoModelWrapper, ModelSpecifications

# %%
def handle_special_mteb_results(data):
    special_benchmarks = ['STS17', 'AmazonCounterfactualClassification']

    if data.get('task_name') not in special_benchmarks:
        assert len(data.get('scores').get('test')) == 1, \
            f"Expected 1 score for {data.get('task_name')}, got {len(data.get('scores').get('test'))}"
        
        return data.get('scores').get('test')[0].get('main_score')
    
    if data.get('task_name') == 'STS17':
        scores = data.get('scores', {}).get('test', [])
        filtered_scores = [
            score for score in scores 
            if score.get('languages') == ['eng-Latn']
        ]
        assert len(filtered_scores) == 1
        return filtered_scores[0].get('main_score')

    elif data.get('task_name') == 'AmazonCounterfactualClassification':
        scores = data.get('scores', {}).get('test', [])
        filtered_scores = [
            score for score in scores 
            if score.get('hf_subset') in ['en', 'en-ext']
        ]
        assert len(filtered_scores) == 2

        english_score = filtered_scores[0].get('main_score')
        english_ext_score = filtered_scores[1].get('main_score') # harder superset, described in Sec 3.3 of https://aclanthology.org/2021.emnlp-main.568.pdf

        return (english_score + english_ext_score) / 2
    else:
        raise ValueError(f"Special benchmark handling for {data.get('task_name')} not found")
    
def get_task_type_from_task_name(task_name: str):
    mteb_task = mteb.get_task(task_name)
    return mteb_task.metadata.type

def get_dataset_name_from_task_name(task_name: str):
    mteb_task = mteb.get_task(task_name)
    return mteb_task.metadata.dataset['path']
        
def load_layerwise_results_for_specific_model(model_specs: ModelSpecifications):
    model_family = model_specs.model_family
    model_size = model_specs.model_size
    revision = model_specs.revision
    
    results = {}
    
    # load metrics
    results['metrics'] = {}
    metrics_load_dir = f"results/{model_family}/{model_size}/{revision}/metrics/"
    for dataset_dir in glob.glob(f"{metrics_load_dir}/**", recursive=True):
        if os.path.isdir(dataset_dir):
            dataset_name = os.path.relpath(dataset_dir, metrics_load_dir)

            results['metrics'][dataset_name] = {}
            for file_path in glob.glob(f"{dataset_dir}/*.pkl"):
                with open(file_path, "rb") as f:
                    key = os.path.basename(file_path)[:-4]
                    results['metrics'][dataset_name][key] = pickle.load(f)
            
            if results['metrics'][dataset_name] == {}:
                # pop superfolders
                results['metrics'].pop(dataset_name)

    # load mteb metrics
    mteb_load_dir = f"results/{model_family}/{model_size}/{revision}/mteb/"
    results['mteb'] = {}
    last_layer_tests = []
    for layer_dir in glob.glob(f"{mteb_load_dir}/layer_*"):
        
        for json_file in glob.glob(f"{layer_dir}/*.json"):
            dataset_name = os.path.basename(json_file)[:-5]
            is_last_layer = 'last' in layer_dir
            if is_last_layer:
                last_layer_tests.append(dataset_name)

            if dataset_name == 'model_meta':
                continue

            if dataset_name not in results['mteb']:
                results['mteb'][dataset_name] = {}
                results['mteb'][dataset_name]['scores'] = []
                results['mteb'][dataset_name]['time_elapsed'] = []
            with open(json_file, 'r') as f:
                data = json.load(f)
                main_score = handle_special_mteb_results(data)
                results['mteb'][dataset_name]['scores'].append(main_score)

                time_elapsed = data.get('evaluation_time', None)
                results['mteb'][dataset_name]['time_elapsed'].append(time_elapsed)
                
                if 'task_type' not in results['mteb'][dataset_name]:
                    results['mteb'][dataset_name]['task_type'] = get_task_type_from_task_name(dataset_name)

    # remove mteb results that were not computed for the last layer
    results['mteb'] = {dataset: data for dataset, data in results['mteb'].items() if dataset in last_layer_tests}

    # # add new metric that is dime divided by dataset entropy
    # for dataset_name, dataset_data in results['metrics'].items():

    #     dataset_data['dime_over_entropy'] = {}
    #     for normalization_type, normalization_data in dataset_data['dime'].items():
    #         dataset_data['dime_over_entropy'][normalization_type] = np.array(dataset_data['dime'][normalization_type]) / np.array(dataset_data['entropy_dataset'][normalization_type])
    
    return results

# %%
model_family = 'Pythia'
model_size = '14m'
revision = 'main'

model_specs = ModelSpecifications(model_family, model_size, revision=revision)
results = load_layerwise_results_for_specific_model(model_specs)

# %% [markdown]
# # Time Taken To Evaluate Each Layer

# %%
import matplotlib.pyplot as plt

total_time_elapsed_per_layer = {}
for dataset, data in results['mteb'].items():
    for layer, time in enumerate(data['time_elapsed']):
        if layer not in total_time_elapsed_per_layer:
            total_time_elapsed_per_layer[layer] = 0
        if time is not None:
            total_time_elapsed_per_layer[layer] += time

# Sort the dictionary by layer number
sorted_times = sorted(total_time_elapsed_per_layer.items())

# Separate layers and times for plotting
layers, times = zip(*sorted_times)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(layers, times, marker='o')
plt.title(f'Total Evaluation Time per Layer for {model_family} {model_size}')
plt.xlabel('Layer')
plt.ylabel('Total Time (seconds)')
plt.grid(True)

# Add text labels for each point
for layer, time in sorted_times:
    plt.text(layer, time, f'{time:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

print(total_time_elapsed_per_layer)
# Out:
# {0: 1224.0296988487244, 1: 1537.076404094696, 2: 1483.4417626857758, 3: 1426.5811371803284, 4: 1580.0492796897888, 5: 1389.9661979675293, 6: 1337.913664340973}

# %% [markdown]
# # One Model - Scores per layer per task

# %%
import matplotlib.pyplot as plt
import numpy as np

model_family = 'mamba'
model_size = '370m'
revision = 'main'

model_specs = ModelSpecifications(model_family, model_size, revision=revision)
results = load_layerwise_results_for_specific_model(model_specs)

# Group tasks by task type
task_types = {}
for task, data in results['mteb'].items():
    task_type = data['task_type']
    if task_type not in task_types:
        task_types[task_type] = {}
    task_types[task_type][task] = data

# find tasks that were not computed for each layer
for task_type, tasks in task_types.items():
    for task, data in tasks.items():
        for layer, score in enumerate(data['scores']):
            if score is None:
                print(f"Task: {task}, Layer: {layer} not computed")
            else:
                print(f"Task: {task}, Layer: {layer} computed")


# Create subplots
num_task_types = len(task_types)
fig, axs = plt.subplots(num_task_types, 1, figsize=(12, 5*num_task_types), sharex=True)

for i, (task_type, tasks) in enumerate(task_types.items()):
    ax = axs[i] if num_task_types > 1 else axs
    all_scores = []
    
    for task, data in tasks.items():
        scores = data['scores']
        layers = range(len(scores))
        ax.plot(layers, scores, label=task, alpha=0.7, marker='x')
        all_scores.append(scores)
    
    # if all_scores:
    #     average_scores = np.mean(all_scores, axis=0)
    #     ax.plot(layers, average_scores, label='Average', linewidth=3, color='black', marker='x')
    
    ax.set_xlabel('Layer')
    ax.set_ylabel('Score')
    ax.set_title(f'{task_type} Tasks Performance for {model_family} {model_size}')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Task: AskUbuntuDupQuestions, Layer: 0 computed
# Task: AskUbuntuDupQuestions, Layer: 1 computed
# Task: AskUbuntuDupQuestions, Layer: 2 computed
# Task: AskUbuntuDupQuestions, Layer: 3 computed
# Task: AskUbuntuDupQuestions, Layer: 4 computed
# Task: AskUbuntuDupQuestions, Layer: 5 computed
# Task: AskUbuntuDupQuestions, Layer: 6 computed
# Task: AskUbuntuDupQuestions, Layer: 7 computed
# Task: AskUbuntuDupQuestions, Layer: 8 computed
# Task: AskUbuntuDupQuestions, Layer: 9 computed
# Task: AskUbuntuDupQuestions, Layer: 10 computed
# Task: AskUbuntuDupQuestions, Layer: 11 computed
# Task: AskUbuntuDupQuestions, Layer: 12 computed
# Task: AskUbuntuDupQuestions, Layer: 13 computed
# Task: AskUbuntuDupQuestions, Layer: 14 computed
# Task: AskUbuntuDupQuestions, Layer: 15 computed
# Task: AskUbuntuDupQuestions, Layer: 16 computed
# Task: AskUbuntuDupQuestions, Layer: 17 computed
# Task: AskUbuntuDupQuestions, Layer: 18 computed
# Task: AskUbuntuDupQuestions, Layer: 19 computed
# Task: AskUbuntuDupQuestions, Layer: 20 computed
# Task: AskUbuntuDupQuestions, Layer: 21 computed
# Task: AskUbuntuDupQuestions, Layer: 22 computed
# Task: AskUbuntuDupQuestions, Layer: 23 computed
# Task: AskUbuntuDupQuestions, Layer: 24 computed
# Task: AskUbuntuDupQuestions, Layer: 25 computed
# Task: AskUbuntuDupQuestions, Layer: 26 computed
# Task: AskUbuntuDupQuestions, Layer: 27 computed
# Task: AskUbuntuDupQuestions, Layer: 28 computed
# Task: AskUbuntuDupQuestions, Layer: 29 computed
# Task: AskUbuntuDupQuestions, Layer: 30 computed
# Task: AskUbuntuDupQuestions, Layer: 31 computed
# Task: AskUbuntuDupQuestions, Layer: 32 computed
# Task: AskUbuntuDupQuestions, Layer: 33 computed
# Task: AskUbuntuDupQuestions, Layer: 34 computed
# Task: AskUbuntuDupQuestions, Layer: 35 computed
# Task: AskUbuntuDupQuestions, Layer: 36 computed
# Task: SciDocsRR, Layer: 0 computed
# Task: SciDocsRR, Layer: 1 computed
# Task: SciDocsRR, Layer: 2 computed
# Task: SciDocsRR, Layer: 3 computed
# Task: SciDocsRR, Layer: 4 computed
# Task: SciDocsRR, Layer: 5 computed
# Task: SciDocsRR, Layer: 6 computed
# Task: SciDocsRR, Layer: 7 computed
# Task: SciDocsRR, Layer: 8 computed
# Task: SciDocsRR, Layer: 9 computed
# Task: SciDocsRR, Layer: 10 computed
# Task: SciDocsRR, Layer: 11 computed
# Task: SciDocsRR, Layer: 12 computed
# Task: SciDocsRR, Layer: 13 computed
# Task: SciDocsRR, Layer: 14 computed
# Task: SciDocsRR, Layer: 15 computed
# Task: SciDocsRR, Layer: 16 computed
# Task: SciDocsRR, Layer: 17 computed
# Task: SciDocsRR, Layer: 18 computed
# Task: SciDocsRR, Layer: 19 computed
# Task: SciDocsRR, Layer: 20 computed
# Task: SciDocsRR, Layer: 21 computed
# Task: SciDocsRR, Layer: 22 computed
# Task: SciDocsRR, Layer: 23 computed
# Task: SciDocsRR, Layer: 24 computed
# Task: SciDocsRR, Layer: 25 computed
# Task: SciDocsRR, Layer: 26 computed
# Task: SciDocsRR, Layer: 27 computed
# Task: SciDocsRR, Layer: 28 computed
# Task: SciDocsRR, Layer: 29 computed
# Task: SciDocsRR, Layer: 30 computed
# Task: SciDocsRR, Layer: 31 computed
# Task: SciDocsRR, Layer: 32 computed
# Task: MindSmallReranking, Layer: 0 computed
# Task: MindSmallReranking, Layer: 1 computed
# Task: MindSmallReranking, Layer: 2 computed
# Task: MindSmallReranking, Layer: 3 computed
# Task: MindSmallReranking, Layer: 4 computed
# Task: MindSmallReranking, Layer: 5 computed
# Task: MindSmallReranking, Layer: 6 computed
# Task: MindSmallReranking, Layer: 7 computed
# Task: MindSmallReranking, Layer: 8 computed
# Task: MindSmallReranking, Layer: 9 computed
# Task: MindSmallReranking, Layer: 10 computed
# Task: MindSmallReranking, Layer: 11 computed
# Task: MindSmallReranking, Layer: 12 computed
# Task: MindSmallReranking, Layer: 13 computed
# Task: MindSmallReranking, Layer: 14 computed
# Task: MindSmallReranking, Layer: 15 computed
# Task: MindSmallReranking, Layer: 16 computed
# Task: MindSmallReranking, Layer: 17 computed
# Task: MindSmallReranking, Layer: 18 computed
# Task: MindSmallReranking, Layer: 19 computed
# Task: MindSmallReranking, Layer: 20 computed
# Task: MindSmallReranking, Layer: 21 computed
# Task: MindSmallReranking, Layer: 22 computed
# Task: MindSmallReranking, Layer: 23 computed
# Task: MindSmallReranking, Layer: 24 computed
# Task: MindSmallReranking, Layer: 25 computed
# Task: MindSmallReranking, Layer: 26 computed
# Task: MindSmallReranking, Layer: 27 computed
# Task: MindSmallReranking, Layer: 28 computed
# Task: MindSmallReranking, Layer: 29 computed
# Task: MindSmallReranking, Layer: 30 computed
# Task: MindSmallReranking, Layer: 31 computed
# Task: MindSmallReranking, Layer: 32 computed
# Task: MindSmallReranking, Layer: 33 computed
# Task: MindSmallReranking, Layer: 34 computed
# Task: MindSmallReranking, Layer: 35 computed
# Task: MindSmallReranking, Layer: 36 computed
# Task: StackOverflowDupQuestions, Layer: 0 computed
# Task: StackOverflowDupQuestions, Layer: 1 computed
# Task: StackOverflowDupQuestions, Layer: 2 computed
# Task: StackOverflowDupQuestions, Layer: 3 computed
# Task: StackOverflowDupQuestions, Layer: 4 computed
# Task: StackOverflowDupQuestions, Layer: 5 computed
# Task: StackOverflowDupQuestions, Layer: 6 computed
# Task: StackOverflowDupQuestions, Layer: 7 computed
# Task: StackOverflowDupQuestions, Layer: 8 computed
# Task: StackOverflowDupQuestions, Layer: 9 computed
# Task: StackOverflowDupQuestions, Layer: 10 computed
# Task: StackOverflowDupQuestions, Layer: 11 computed
# Task: StackOverflowDupQuestions, Layer: 12 computed
# Task: StackOverflowDupQuestions, Layer: 13 computed
# Task: StackOverflowDupQuestions, Layer: 14 computed
# Task: StackOverflowDupQuestions, Layer: 15 computed
# Task: StackOverflowDupQuestions, Layer: 16 computed
# Task: StackOverflowDupQuestions, Layer: 17 computed
# Task: StackOverflowDupQuestions, Layer: 18 computed
# Task: StackOverflowDupQuestions, Layer: 19 computed
# Task: StackOverflowDupQuestions, Layer: 20 computed
# Task: StackOverflowDupQuestions, Layer: 21 computed
# Task: StackOverflowDupQuestions, Layer: 22 computed
# Task: StackOverflowDupQuestions, Layer: 23 computed
# Task: StackOverflowDupQuestions, Layer: 24 computed
# Task: StackOverflowDupQuestions, Layer: 25 computed
# Task: StackOverflowDupQuestions, Layer: 26 computed
# Task: StackOverflowDupQuestions, Layer: 27 computed
# Task: StackOverflowDupQuestions, Layer: 28 computed
# Task: StackOverflowDupQuestions, Layer: 29 computed
# Task: StackOverflowDupQuestions, Layer: 30 computed
# Task: StackOverflowDupQuestions, Layer: 31 computed
# Task: StackOverflowDupQuestions, Layer: 32 computed
# Task: Banking77Classification, Layer: 0 computed
# Task: Banking77Classification, Layer: 1 computed
# Task: Banking77Classification, Layer: 2 computed
# Task: Banking77Classification, Layer: 3 computed
# Task: Banking77Classification, Layer: 4 computed
# Task: Banking77Classification, Layer: 5 computed
# Task: Banking77Classification, Layer: 6 computed
# Task: Banking77Classification, Layer: 7 computed
# Task: Banking77Classification, Layer: 8 computed
# Task: Banking77Classification, Layer: 9 computed
# Task: Banking77Classification, Layer: 10 computed
# Task: Banking77Classification, Layer: 11 computed
# Task: Banking77Classification, Layer: 12 computed
# Task: Banking77Classification, Layer: 13 computed
# Task: Banking77Classification, Layer: 14 computed
# Task: Banking77Classification, Layer: 15 computed
# Task: Banking77Classification, Layer: 16 computed
# Task: Banking77Classification, Layer: 17 computed
# Task: Banking77Classification, Layer: 18 computed
# Task: Banking77Classification, Layer: 19 computed
# Task: Banking77Classification, Layer: 20 computed
# Task: Banking77Classification, Layer: 21 computed
# Task: Banking77Classification, Layer: 22 computed
# Task: Banking77Classification, Layer: 23 computed
# Task: Banking77Classification, Layer: 24 computed
# Task: Banking77Classification, Layer: 25 computed
# Task: Banking77Classification, Layer: 26 computed
# Task: Banking77Classification, Layer: 27 computed
# Task: Banking77Classification, Layer: 28 computed
# Task: Banking77Classification, Layer: 29 computed
# Task: Banking77Classification, Layer: 30 computed
# Task: Banking77Classification, Layer: 31 computed
# Task: Banking77Classification, Layer: 32 computed
# Task: Banking77Classification, Layer: 33 computed
# Task: Banking77Classification, Layer: 34 computed
# Task: Banking77Classification, Layer: 35 computed
# Task: Banking77Classification, Layer: 36 computed
# Task: MTOPDomainClassification, Layer: 0 computed
# Task: MTOPDomainClassification, Layer: 1 computed
# Task: MTOPDomainClassification, Layer: 2 computed
# Task: MTOPDomainClassification, Layer: 3 computed
# Task: MTOPDomainClassification, Layer: 4 computed
# Task: MTOPDomainClassification, Layer: 5 computed
# Task: MTOPDomainClassification, Layer: 6 computed
# Task: MTOPDomainClassification, Layer: 7 computed
# Task: MTOPDomainClassification, Layer: 8 computed
# Task: MTOPDomainClassification, Layer: 9 computed
# Task: MTOPDomainClassification, Layer: 10 computed
# Task: MTOPDomainClassification, Layer: 11 computed
# Task: MTOPDomainClassification, Layer: 12 computed
# Task: MTOPDomainClassification, Layer: 13 computed
# Task: MTOPDomainClassification, Layer: 14 computed
# Task: MTOPDomainClassification, Layer: 15 computed
# Task: MTOPDomainClassification, Layer: 16 computed
# Task: MTOPDomainClassification, Layer: 17 computed
# Task: MTOPDomainClassification, Layer: 18 computed
# Task: MTOPDomainClassification, Layer: 19 computed
# Task: MTOPDomainClassification, Layer: 20 computed
# Task: MTOPDomainClassification, Layer: 21 computed
# Task: MTOPDomainClassification, Layer: 22 computed
# Task: MTOPDomainClassification, Layer: 23 computed
# Task: MTOPDomainClassification, Layer: 24 computed
# Task: MTOPDomainClassification, Layer: 25 computed
# Task: MTOPDomainClassification, Layer: 26 computed
# Task: MTOPDomainClassification, Layer: 27 computed
# Task: MTOPDomainClassification, Layer: 28 computed
# Task: MTOPDomainClassification, Layer: 29 computed
# Task: MTOPDomainClassification, Layer: 30 computed
# Task: MTOPDomainClassification, Layer: 31 computed
# Task: MTOPDomainClassification, Layer: 32 computed
# Task: MTOPDomainClassification, Layer: 33 computed
# Task: MTOPDomainClassification, Layer: 34 computed
# Task: MTOPDomainClassification, Layer: 35 computed
# Task: MTOPDomainClassification, Layer: 36 computed
# Task: EmotionClassification, Layer: 0 computed
# Task: EmotionClassification, Layer: 1 computed
# Task: EmotionClassification, Layer: 2 computed
# Task: EmotionClassification, Layer: 3 computed
# Task: EmotionClassification, Layer: 4 computed
# Task: EmotionClassification, Layer: 5 computed
# Task: EmotionClassification, Layer: 6 computed
# Task: EmotionClassification, Layer: 7 computed
# Task: EmotionClassification, Layer: 8 computed
# Task: EmotionClassification, Layer: 9 computed
# Task: EmotionClassification, Layer: 10 computed
# Task: EmotionClassification, Layer: 11 computed
# Task: EmotionClassification, Layer: 12 computed
# Task: EmotionClassification, Layer: 13 computed
# Task: EmotionClassification, Layer: 14 computed
# Task: EmotionClassification, Layer: 15 computed
# Task: EmotionClassification, Layer: 16 computed
# Task: EmotionClassification, Layer: 17 computed
# Task: EmotionClassification, Layer: 18 computed
# Task: EmotionClassification, Layer: 19 computed
# Task: EmotionClassification, Layer: 20 computed
# Task: EmotionClassification, Layer: 21 computed
# Task: EmotionClassification, Layer: 22 computed
# Task: EmotionClassification, Layer: 23 computed
# Task: EmotionClassification, Layer: 24 computed
# Task: EmotionClassification, Layer: 25 computed
# Task: EmotionClassification, Layer: 26 computed
# Task: EmotionClassification, Layer: 27 computed
# Task: EmotionClassification, Layer: 28 computed
# Task: EmotionClassification, Layer: 29 computed
# Task: EmotionClassification, Layer: 30 computed
# Task: EmotionClassification, Layer: 31 computed
# Task: EmotionClassification, Layer: 32 computed
# Task: EmotionClassification, Layer: 33 computed
# Task: EmotionClassification, Layer: 34 computed
# Task: EmotionClassification, Layer: 35 computed
# Task: EmotionClassification, Layer: 36 computed
# Task: MTOPIntentClassification, Layer: 0 computed
# Task: MTOPIntentClassification, Layer: 1 computed
# Task: MTOPIntentClassification, Layer: 2 computed
# Task: MTOPIntentClassification, Layer: 3 computed
# Task: MTOPIntentClassification, Layer: 4 computed
# Task: MTOPIntentClassification, Layer: 5 computed
# Task: MTOPIntentClassification, Layer: 6 computed
# Task: MTOPIntentClassification, Layer: 7 computed
# Task: MTOPIntentClassification, Layer: 8 computed
# Task: MTOPIntentClassification, Layer: 9 computed
# Task: MTOPIntentClassification, Layer: 10 computed
# Task: MTOPIntentClassification, Layer: 11 computed
# Task: MTOPIntentClassification, Layer: 12 computed
# Task: MTOPIntentClassification, Layer: 13 computed
# Task: MTOPIntentClassification, Layer: 14 computed
# Task: MTOPIntentClassification, Layer: 15 computed
# Task: MTOPIntentClassification, Layer: 16 computed
# Task: MTOPIntentClassification, Layer: 17 computed
# Task: MTOPIntentClassification, Layer: 18 computed
# Task: MTOPIntentClassification, Layer: 19 computed
# Task: MTOPIntentClassification, Layer: 20 computed
# Task: MTOPIntentClassification, Layer: 21 computed
# Task: MTOPIntentClassification, Layer: 22 computed
# Task: MTOPIntentClassification, Layer: 23 computed
# Task: MTOPIntentClassification, Layer: 24 computed
# Task: MTOPIntentClassification, Layer: 25 computed
# Task: MTOPIntentClassification, Layer: 26 computed
# Task: MTOPIntentClassification, Layer: 27 computed
# Task: MTOPIntentClassification, Layer: 28 computed
# Task: MTOPIntentClassification, Layer: 29 computed
# Task: MTOPIntentClassification, Layer: 30 computed
# Task: MTOPIntentClassification, Layer: 31 computed
# Task: MTOPIntentClassification, Layer: 32 computed
# Task: MTOPIntentClassification, Layer: 33 computed
# Task: MTOPIntentClassification, Layer: 34 computed
# Task: MTOPIntentClassification, Layer: 35 computed
# Task: MTOPIntentClassification, Layer: 36 computed
# Task: AmazonReviewsClassification, Layer: 0 computed
# Task: AmazonReviewsClassification, Layer: 1 computed
# Task: AmazonReviewsClassification, Layer: 2 computed
# Task: AmazonReviewsClassification, Layer: 3 computed
# Task: AmazonReviewsClassification, Layer: 4 computed
# Task: AmazonReviewsClassification, Layer: 5 computed
# Task: AmazonReviewsClassification, Layer: 6 computed
# Task: AmazonReviewsClassification, Layer: 7 computed
# Task: AmazonReviewsClassification, Layer: 8 computed
# Task: AmazonReviewsClassification, Layer: 9 computed
# Task: AmazonReviewsClassification, Layer: 10 computed
# Task: AmazonReviewsClassification, Layer: 11 computed
# Task: AmazonReviewsClassification, Layer: 12 computed
# Task: AmazonReviewsClassification, Layer: 13 computed
# Task: AmazonReviewsClassification, Layer: 14 computed
# Task: AmazonReviewsClassification, Layer: 15 computed
# Task: AmazonReviewsClassification, Layer: 16 computed
# Task: AmazonReviewsClassification, Layer: 17 computed
# Task: AmazonReviewsClassification, Layer: 18 computed
# Task: AmazonReviewsClassification, Layer: 19 computed
# Task: AmazonReviewsClassification, Layer: 20 computed
# Task: AmazonReviewsClassification, Layer: 21 computed
# Task: AmazonReviewsClassification, Layer: 22 computed
# Task: AmazonReviewsClassification, Layer: 23 computed
# Task: AmazonReviewsClassification, Layer: 24 computed
# Task: AmazonReviewsClassification, Layer: 25 computed
# Task: AmazonReviewsClassification, Layer: 26 computed
# Task: AmazonReviewsClassification, Layer: 27 computed
# Task: AmazonReviewsClassification, Layer: 28 computed
# Task: AmazonReviewsClassification, Layer: 29 computed
# Task: AmazonReviewsClassification, Layer: 30 computed
# Task: AmazonReviewsClassification, Layer: 31 computed
# Task: AmazonReviewsClassification, Layer: 32 computed
# Task: AmazonReviewsClassification, Layer: 33 computed
# Task: AmazonReviewsClassification, Layer: 34 computed
# Task: AmazonReviewsClassification, Layer: 35 computed
# Task: AmazonReviewsClassification, Layer: 36 computed
# Task: MassiveIntentClassification, Layer: 0 computed
# Task: MassiveIntentClassification, Layer: 1 computed
# Task: MassiveIntentClassification, Layer: 2 computed
# Task: MassiveIntentClassification, Layer: 3 computed
# Task: MassiveIntentClassification, Layer: 4 computed
# Task: MassiveIntentClassification, Layer: 5 computed
# Task: MassiveIntentClassification, Layer: 6 computed
# Task: MassiveIntentClassification, Layer: 7 computed
# Task: MassiveIntentClassification, Layer: 8 computed
# Task: MassiveIntentClassification, Layer: 9 computed
# Task: MassiveIntentClassification, Layer: 10 computed
# Task: MassiveIntentClassification, Layer: 11 computed
# Task: MassiveIntentClassification, Layer: 12 computed
# Task: MassiveIntentClassification, Layer: 13 computed
# Task: MassiveIntentClassification, Layer: 14 computed
# Task: MassiveIntentClassification, Layer: 15 computed
# Task: MassiveIntentClassification, Layer: 16 computed
# Task: MassiveIntentClassification, Layer: 17 computed
# Task: MassiveIntentClassification, Layer: 18 computed
# Task: MassiveIntentClassification, Layer: 19 computed
# Task: MassiveIntentClassification, Layer: 20 computed
# Task: MassiveIntentClassification, Layer: 21 computed
# Task: MassiveIntentClassification, Layer: 22 computed
# Task: MassiveIntentClassification, Layer: 23 computed
# Task: MassiveIntentClassification, Layer: 24 computed
# Task: MassiveIntentClassification, Layer: 25 computed
# Task: MassiveIntentClassification, Layer: 26 computed
# Task: MassiveIntentClassification, Layer: 27 computed
# Task: MassiveIntentClassification, Layer: 28 computed
# Task: MassiveIntentClassification, Layer: 29 computed
# Task: MassiveIntentClassification, Layer: 30 computed
# Task: MassiveIntentClassification, Layer: 31 computed
# Task: MassiveIntentClassification, Layer: 32 computed
# Task: MassiveIntentClassification, Layer: 33 computed
# Task: MassiveIntentClassification, Layer: 34 computed
# Task: MassiveIntentClassification, Layer: 35 computed
# Task: MassiveIntentClassification, Layer: 36 computed
# Task: AmazonCounterfactualClassification, Layer: 0 computed
# Task: AmazonCounterfactualClassification, Layer: 1 computed
# Task: AmazonCounterfactualClassification, Layer: 2 computed
# Task: AmazonCounterfactualClassification, Layer: 3 computed
# Task: AmazonCounterfactualClassification, Layer: 4 computed
# Task: AmazonCounterfactualClassification, Layer: 5 computed
# Task: AmazonCounterfactualClassification, Layer: 6 computed
# Task: AmazonCounterfactualClassification, Layer: 7 computed
# Task: AmazonCounterfactualClassification, Layer: 8 computed
# Task: AmazonCounterfactualClassification, Layer: 9 computed
# Task: AmazonCounterfactualClassification, Layer: 10 computed
# Task: AmazonCounterfactualClassification, Layer: 11 computed
# Task: AmazonCounterfactualClassification, Layer: 12 computed
# Task: AmazonCounterfactualClassification, Layer: 13 computed
# Task: AmazonCounterfactualClassification, Layer: 14 computed
# Task: AmazonCounterfactualClassification, Layer: 15 computed
# Task: AmazonCounterfactualClassification, Layer: 16 computed
# Task: AmazonCounterfactualClassification, Layer: 17 computed
# Task: AmazonCounterfactualClassification, Layer: 18 computed
# Task: AmazonCounterfactualClassification, Layer: 19 computed
# Task: AmazonCounterfactualClassification, Layer: 20 computed
# Task: AmazonCounterfactualClassification, Layer: 21 computed
# Task: AmazonCounterfactualClassification, Layer: 22 computed
# Task: AmazonCounterfactualClassification, Layer: 23 computed
# Task: AmazonCounterfactualClassification, Layer: 24 computed
# Task: AmazonCounterfactualClassification, Layer: 25 computed
# Task: AmazonCounterfactualClassification, Layer: 26 computed
# Task: AmazonCounterfactualClassification, Layer: 27 computed
# Task: AmazonCounterfactualClassification, Layer: 28 computed
# Task: AmazonCounterfactualClassification, Layer: 29 computed
# Task: AmazonCounterfactualClassification, Layer: 30 computed
# Task: AmazonCounterfactualClassification, Layer: 31 computed
# Task: AmazonCounterfactualClassification, Layer: 32 computed
# Task: AmazonCounterfactualClassification, Layer: 33 computed
# Task: AmazonCounterfactualClassification, Layer: 34 computed
# Task: AmazonCounterfactualClassification, Layer: 35 computed
# Task: AmazonCounterfactualClassification, Layer: 36 computed
# Task: AmazonCounterfactualClassification, Layer: 37 computed
# Task: AmazonCounterfactualClassification, Layer: 38 computed
# Task: AmazonCounterfactualClassification, Layer: 39 computed
# Task: AmazonCounterfactualClassification, Layer: 40 computed
# Task: AmazonCounterfactualClassification, Layer: 41 computed
# Task: AmazonCounterfactualClassification, Layer: 42 computed
# Task: AmazonCounterfactualClassification, Layer: 43 computed
# Task: AmazonCounterfactualClassification, Layer: 44 computed
# Task: AmazonCounterfactualClassification, Layer: 45 computed
# Task: AmazonCounterfactualClassification, Layer: 46 computed
# Task: AmazonCounterfactualClassification, Layer: 47 computed
# Task: AmazonCounterfactualClassification, Layer: 48 computed
# Task: MassiveScenarioClassification, Layer: 0 computed
# Task: MassiveScenarioClassification, Layer: 1 computed
# Task: MassiveScenarioClassification, Layer: 2 computed
# Task: MassiveScenarioClassification, Layer: 3 computed
# Task: MassiveScenarioClassification, Layer: 4 computed
# Task: MassiveScenarioClassification, Layer: 5 computed
# Task: MassiveScenarioClassification, Layer: 6 computed
# Task: MassiveScenarioClassification, Layer: 7 computed
# Task: MassiveScenarioClassification, Layer: 8 computed
# Task: MassiveScenarioClassification, Layer: 9 computed
# Task: MassiveScenarioClassification, Layer: 10 computed
# Task: MassiveScenarioClassification, Layer: 11 computed
# Task: MassiveScenarioClassification, Layer: 12 computed
# Task: MassiveScenarioClassification, Layer: 13 computed
# Task: MassiveScenarioClassification, Layer: 14 computed
# Task: MassiveScenarioClassification, Layer: 15 computed
# Task: MassiveScenarioClassification, Layer: 16 computed
# Task: MassiveScenarioClassification, Layer: 17 computed
# Task: MassiveScenarioClassification, Layer: 18 computed
# Task: MassiveScenarioClassification, Layer: 19 computed
# Task: MassiveScenarioClassification, Layer: 20 computed
# Task: MassiveScenarioClassification, Layer: 21 computed
# Task: MassiveScenarioClassification, Layer: 22 computed
# Task: MassiveScenarioClassification, Layer: 23 computed
# Task: MassiveScenarioClassification, Layer: 24 computed
# Task: MassiveScenarioClassification, Layer: 25 computed
# Task: MassiveScenarioClassification, Layer: 26 computed
# Task: MassiveScenarioClassification, Layer: 27 computed
# Task: MassiveScenarioClassification, Layer: 28 computed
# Task: MassiveScenarioClassification, Layer: 29 computed
# Task: MassiveScenarioClassification, Layer: 30 computed
# Task: MassiveScenarioClassification, Layer: 31 computed
# Task: MassiveScenarioClassification, Layer: 32 computed
# Task: MassiveScenarioClassification, Layer: 33 computed
# Task: MassiveScenarioClassification, Layer: 34 computed
# Task: MassiveScenarioClassification, Layer: 35 computed
# Task: MassiveScenarioClassification, Layer: 36 computed
# Task: ToxicConversationsClassification, Layer: 0 computed
# Task: ToxicConversationsClassification, Layer: 1 computed
# Task: ToxicConversationsClassification, Layer: 2 computed
# Task: ToxicConversationsClassification, Layer: 3 computed
# Task: ToxicConversationsClassification, Layer: 4 computed
# Task: ToxicConversationsClassification, Layer: 5 computed
# Task: ToxicConversationsClassification, Layer: 6 computed
# Task: ToxicConversationsClassification, Layer: 7 computed
# Task: ToxicConversationsClassification, Layer: 8 computed
# Task: ToxicConversationsClassification, Layer: 9 computed
# Task: ToxicConversationsClassification, Layer: 10 computed
# Task: ToxicConversationsClassification, Layer: 11 computed
# Task: ToxicConversationsClassification, Layer: 12 computed
# Task: ToxicConversationsClassification, Layer: 13 computed
# Task: ToxicConversationsClassification, Layer: 14 computed
# Task: ToxicConversationsClassification, Layer: 15 computed
# Task: ToxicConversationsClassification, Layer: 16 computed
# Task: ToxicConversationsClassification, Layer: 17 computed
# Task: ToxicConversationsClassification, Layer: 18 computed
# Task: ToxicConversationsClassification, Layer: 19 computed
# Task: ToxicConversationsClassification, Layer: 20 computed
# Task: ToxicConversationsClassification, Layer: 21 computed
# Task: ToxicConversationsClassification, Layer: 22 computed
# Task: ToxicConversationsClassification, Layer: 23 computed
# Task: ToxicConversationsClassification, Layer: 24 computed
# Task: ToxicConversationsClassification, Layer: 25 computed
# Task: ToxicConversationsClassification, Layer: 26 computed
# Task: ToxicConversationsClassification, Layer: 27 computed
# Task: ToxicConversationsClassification, Layer: 28 computed
# Task: ToxicConversationsClassification, Layer: 29 computed
# Task: ToxicConversationsClassification, Layer: 30 computed
# Task: ToxicConversationsClassification, Layer: 31 computed
# Task: ToxicConversationsClassification, Layer: 32 computed
# Task: TweetSentimentExtractionClassification, Layer: 0 computed
# Task: TweetSentimentExtractionClassification, Layer: 1 computed
# Task: TweetSentimentExtractionClassification, Layer: 2 computed
# Task: TweetSentimentExtractionClassification, Layer: 3 computed
# Task: TweetSentimentExtractionClassification, Layer: 4 computed
# Task: TweetSentimentExtractionClassification, Layer: 5 computed
# Task: TweetSentimentExtractionClassification, Layer: 6 computed
# Task: TweetSentimentExtractionClassification, Layer: 7 computed
# Task: TweetSentimentExtractionClassification, Layer: 8 computed
# Task: TweetSentimentExtractionClassification, Layer: 9 computed
# Task: TweetSentimentExtractionClassification, Layer: 10 computed
# Task: TweetSentimentExtractionClassification, Layer: 11 computed
# Task: TweetSentimentExtractionClassification, Layer: 12 computed
# Task: TweetSentimentExtractionClassification, Layer: 13 computed
# Task: TweetSentimentExtractionClassification, Layer: 14 computed
# Task: TweetSentimentExtractionClassification, Layer: 15 computed
# Task: TweetSentimentExtractionClassification, Layer: 16 computed
# Task: TweetSentimentExtractionClassification, Layer: 17 computed
# Task: TweetSentimentExtractionClassification, Layer: 18 computed
# Task: TweetSentimentExtractionClassification, Layer: 19 computed
# Task: TweetSentimentExtractionClassification, Layer: 20 computed
# Task: TweetSentimentExtractionClassification, Layer: 21 computed
# Task: TweetSentimentExtractionClassification, Layer: 22 computed
# Task: TweetSentimentExtractionClassification, Layer: 23 computed
# Task: TweetSentimentExtractionClassification, Layer: 24 computed
# Task: TweetSentimentExtractionClassification, Layer: 25 computed
# Task: TweetSentimentExtractionClassification, Layer: 26 computed
# Task: TweetSentimentExtractionClassification, Layer: 27 computed
# Task: TweetSentimentExtractionClassification, Layer: 28 computed
# Task: TweetSentimentExtractionClassification, Layer: 29 computed
# Task: TweetSentimentExtractionClassification, Layer: 30 computed
# Task: TweetSentimentExtractionClassification, Layer: 31 computed
# Task: TweetSentimentExtractionClassification, Layer: 32 computed
# Task: StackExchangeClustering, Layer: 0 computed
# Task: StackExchangeClustering, Layer: 1 computed
# Task: StackExchangeClustering, Layer: 2 computed
# Task: StackExchangeClustering, Layer: 3 computed
# Task: StackExchangeClustering, Layer: 4 computed
# Task: StackExchangeClustering, Layer: 5 computed
# Task: StackExchangeClustering, Layer: 6 computed
# Task: StackExchangeClustering, Layer: 7 computed
# Task: StackExchangeClustering, Layer: 8 computed
# Task: StackExchangeClustering, Layer: 9 computed
# Task: StackExchangeClustering, Layer: 10 computed
# Task: StackExchangeClustering, Layer: 11 computed
# Task: StackExchangeClustering, Layer: 12 computed
# Task: StackExchangeClustering, Layer: 13 computed
# Task: StackExchangeClustering, Layer: 14 computed
# Task: StackExchangeClustering, Layer: 15 computed
# Task: StackExchangeClustering, Layer: 16 computed
# Task: StackExchangeClustering, Layer: 17 computed
# Task: StackExchangeClustering, Layer: 18 computed
# Task: StackExchangeClustering, Layer: 19 computed
# Task: StackExchangeClustering, Layer: 20 computed
# Task: StackExchangeClustering, Layer: 21 computed
# Task: StackExchangeClustering, Layer: 22 computed
# Task: StackExchangeClustering, Layer: 23 computed
# Task: StackExchangeClustering, Layer: 24 computed
# Task: StackExchangeClustering, Layer: 25 computed
# Task: StackExchangeClustering, Layer: 26 computed
# Task: StackExchangeClustering, Layer: 27 computed
# Task: StackExchangeClustering, Layer: 28 computed
# Task: StackExchangeClustering, Layer: 29 computed
# Task: StackExchangeClustering, Layer: 30 computed
# Task: StackExchangeClustering, Layer: 31 computed
# Task: TwentyNewsgroupsClustering, Layer: 0 computed
# Task: TwentyNewsgroupsClustering, Layer: 1 computed
# Task: TwentyNewsgroupsClustering, Layer: 2 computed
# Task: TwentyNewsgroupsClustering, Layer: 3 computed
# Task: TwentyNewsgroupsClustering, Layer: 4 computed
# Task: TwentyNewsgroupsClustering, Layer: 5 computed
# Task: TwentyNewsgroupsClustering, Layer: 6 computed
# Task: TwentyNewsgroupsClustering, Layer: 7 computed
# Task: TwentyNewsgroupsClustering, Layer: 8 computed
# Task: TwentyNewsgroupsClustering, Layer: 9 computed
# Task: TwentyNewsgroupsClustering, Layer: 10 computed
# Task: TwentyNewsgroupsClustering, Layer: 11 computed
# Task: TwentyNewsgroupsClustering, Layer: 12 computed
# Task: TwentyNewsgroupsClustering, Layer: 13 computed
# Task: TwentyNewsgroupsClustering, Layer: 14 computed
# Task: TwentyNewsgroupsClustering, Layer: 15 computed
# Task: TwentyNewsgroupsClustering, Layer: 16 computed
# Task: TwentyNewsgroupsClustering, Layer: 17 computed
# Task: TwentyNewsgroupsClustering, Layer: 18 computed
# Task: TwentyNewsgroupsClustering, Layer: 19 computed
# Task: TwentyNewsgroupsClustering, Layer: 20 computed
# Task: TwentyNewsgroupsClustering, Layer: 21 computed
# Task: TwentyNewsgroupsClustering, Layer: 22 computed
# Task: TwentyNewsgroupsClustering, Layer: 23 computed
# Task: TwentyNewsgroupsClustering, Layer: 24 computed
# Task: TwentyNewsgroupsClustering, Layer: 25 computed
# Task: TwentyNewsgroupsClustering, Layer: 26 computed
# Task: TwentyNewsgroupsClustering, Layer: 27 computed
# Task: TwentyNewsgroupsClustering, Layer: 28 computed
# Task: TwentyNewsgroupsClustering, Layer: 29 computed
# Task: TwentyNewsgroupsClustering, Layer: 30 computed
# Task: TwentyNewsgroupsClustering, Layer: 31 computed
# Task: TwentyNewsgroupsClustering, Layer: 32 computed
# Task: BiorxivClusteringS2S, Layer: 0 computed
# Task: BiorxivClusteringS2S, Layer: 1 computed
# Task: BiorxivClusteringS2S, Layer: 2 computed
# Task: BiorxivClusteringS2S, Layer: 3 computed
# Task: BiorxivClusteringS2S, Layer: 4 computed
# Task: BiorxivClusteringS2S, Layer: 5 computed
# Task: BiorxivClusteringS2S, Layer: 6 computed
# Task: BiorxivClusteringS2S, Layer: 7 computed
# Task: BiorxivClusteringS2S, Layer: 8 computed
# Task: BiorxivClusteringS2S, Layer: 9 computed
# Task: BiorxivClusteringS2S, Layer: 10 computed
# Task: BiorxivClusteringS2S, Layer: 11 computed
# Task: BiorxivClusteringS2S, Layer: 12 computed
# Task: BiorxivClusteringS2S, Layer: 13 computed
# Task: BiorxivClusteringS2S, Layer: 14 computed
# Task: BiorxivClusteringS2S, Layer: 15 computed
# Task: BiorxivClusteringS2S, Layer: 16 computed
# Task: BiorxivClusteringS2S, Layer: 17 computed
# Task: BiorxivClusteringS2S, Layer: 18 computed
# Task: BiorxivClusteringS2S, Layer: 19 computed
# Task: BiorxivClusteringS2S, Layer: 20 computed
# Task: BiorxivClusteringS2S, Layer: 21 computed
# Task: BiorxivClusteringS2S, Layer: 22 computed
# Task: BiorxivClusteringS2S, Layer: 23 computed
# Task: BiorxivClusteringS2S, Layer: 24 computed
# Task: BiorxivClusteringS2S, Layer: 25 computed
# Task: BiorxivClusteringS2S, Layer: 26 computed
# Task: BiorxivClusteringS2S, Layer: 27 computed
# Task: BiorxivClusteringS2S, Layer: 28 computed
# Task: BiorxivClusteringS2S, Layer: 29 computed
# Task: BiorxivClusteringS2S, Layer: 30 computed
# Task: BiorxivClusteringS2S, Layer: 31 computed
# Task: BiorxivClusteringS2S, Layer: 32 computed
# Task: BiorxivClusteringS2S, Layer: 33 computed
# Task: BiorxivClusteringS2S, Layer: 34 computed
# Task: BiorxivClusteringS2S, Layer: 35 computed
# Task: BiorxivClusteringS2S, Layer: 36 computed
# Task: MedrxivClusteringS2S, Layer: 0 computed
# Task: MedrxivClusteringS2S, Layer: 1 computed
# Task: MedrxivClusteringS2S, Layer: 2 computed
# Task: MedrxivClusteringS2S, Layer: 3 computed
# Task: MedrxivClusteringS2S, Layer: 4 computed
# Task: MedrxivClusteringS2S, Layer: 5 computed
# Task: MedrxivClusteringS2S, Layer: 6 computed
# Task: MedrxivClusteringS2S, Layer: 7 computed
# Task: MedrxivClusteringS2S, Layer: 8 computed
# Task: MedrxivClusteringS2S, Layer: 9 computed
# Task: MedrxivClusteringS2S, Layer: 10 computed
# Task: MedrxivClusteringS2S, Layer: 11 computed
# Task: MedrxivClusteringS2S, Layer: 12 computed
# Task: MedrxivClusteringS2S, Layer: 13 computed
# Task: MedrxivClusteringS2S, Layer: 14 computed
# Task: MedrxivClusteringS2S, Layer: 15 computed
# Task: MedrxivClusteringS2S, Layer: 16 computed
# Task: MedrxivClusteringS2S, Layer: 17 computed
# Task: MedrxivClusteringS2S, Layer: 18 computed
# Task: MedrxivClusteringS2S, Layer: 19 computed
# Task: MedrxivClusteringS2S, Layer: 20 computed
# Task: MedrxivClusteringS2S, Layer: 21 computed
# Task: MedrxivClusteringS2S, Layer: 22 computed
# Task: MedrxivClusteringS2S, Layer: 23 computed
# Task: MedrxivClusteringS2S, Layer: 24 computed
# Task: MedrxivClusteringS2S, Layer: 25 computed
# Task: MedrxivClusteringS2S, Layer: 26 computed
# Task: MedrxivClusteringS2S, Layer: 27 computed
# Task: MedrxivClusteringS2S, Layer: 28 computed
# Task: MedrxivClusteringS2S, Layer: 29 computed
# Task: MedrxivClusteringS2S, Layer: 30 computed
# Task: MedrxivClusteringS2S, Layer: 31 computed
# Task: MedrxivClusteringS2S, Layer: 32 computed
# Task: MedrxivClusteringS2S, Layer: 33 computed
# Task: MedrxivClusteringS2S, Layer: 34 computed
# Task: MedrxivClusteringS2S, Layer: 35 computed
# Task: MedrxivClusteringS2S, Layer: 36 computed
# Task: RedditClustering, Layer: 0 computed
# Task: RedditClustering, Layer: 1 computed
# Task: RedditClustering, Layer: 2 computed
# Task: RedditClustering, Layer: 3 computed
# Task: RedditClustering, Layer: 4 computed
# Task: RedditClustering, Layer: 5 computed
# Task: RedditClustering, Layer: 6 computed
# Task: RedditClustering, Layer: 7 computed
# Task: RedditClustering, Layer: 8 computed
# Task: RedditClustering, Layer: 9 computed
# Task: RedditClustering, Layer: 10 computed
# Task: RedditClustering, Layer: 11 computed
# Task: RedditClustering, Layer: 12 computed
# Task: RedditClustering, Layer: 13 computed
# Task: RedditClustering, Layer: 14 computed
# Task: RedditClustering, Layer: 15 computed
# Task: RedditClustering, Layer: 16 computed
# Task: RedditClustering, Layer: 17 computed
# Task: RedditClustering, Layer: 18 computed
# Task: RedditClustering, Layer: 19 computed
# Task: RedditClustering, Layer: 20 computed
# Task: RedditClustering, Layer: 21 computed
# Task: RedditClustering, Layer: 22 computed
# Task: RedditClustering, Layer: 23 computed
# Task: RedditClustering, Layer: 24 computed
# Task: RedditClustering, Layer: 25 computed
# Task: RedditClustering, Layer: 26 computed
# Task: RedditClustering, Layer: 27 computed
# Task: RedditClustering, Layer: 28 computed
# Task: RedditClustering, Layer: 29 computed
# Task: RedditClustering, Layer: 30 computed
# Task: RedditClustering, Layer: 31 computed
# Task: ArxivClusteringS2S, Layer: 0 computed
# Task: ArxivClusteringS2S, Layer: 1 computed
# Task: ArxivClusteringS2S, Layer: 2 computed
# Task: ArxivClusteringS2S, Layer: 3 computed
# Task: ArxivClusteringS2S, Layer: 4 computed
# Task: ArxivClusteringS2S, Layer: 5 computed
# Task: ArxivClusteringS2S, Layer: 6 computed
# Task: ArxivClusteringS2S, Layer: 7 computed
# Task: ArxivClusteringS2S, Layer: 8 computed
# Task: ArxivClusteringS2S, Layer: 9 computed
# Task: ArxivClusteringS2S, Layer: 10 computed
# Task: ArxivClusteringS2S, Layer: 11 computed
# Task: ArxivClusteringS2S, Layer: 12 computed
# Task: ArxivClusteringS2S, Layer: 13 computed
# Task: ArxivClusteringS2S, Layer: 14 computed
# Task: ArxivClusteringS2S, Layer: 15 computed
# Task: ArxivClusteringS2S, Layer: 16 computed
# Task: ArxivClusteringS2S, Layer: 17 computed
# Task: ArxivClusteringS2S, Layer: 18 computed
# Task: ArxivClusteringS2S, Layer: 19 computed
# Task: ArxivClusteringS2S, Layer: 20 computed
# Task: ArxivClusteringS2S, Layer: 21 computed
# Task: ArxivClusteringS2S, Layer: 22 computed
# Task: ArxivClusteringS2S, Layer: 23 computed
# Task: ArxivClusteringS2S, Layer: 24 computed
# Task: ArxivClusteringS2S, Layer: 25 computed
# Task: ArxivClusteringS2S, Layer: 26 computed
# Task: ArxivClusteringS2S, Layer: 27 computed
# Task: ArxivClusteringS2S, Layer: 28 computed
# Task: ArxivClusteringS2S, Layer: 29 computed
# Task: ArxivClusteringS2S, Layer: 30 computed
# Task: ArxivClusteringS2S, Layer: 31 computed
# Task: ArxivClusteringS2S, Layer: 32 computed
# Task: ArxivClusteringS2S, Layer: 33 computed
# Task: ArxivClusteringS2S, Layer: 34 computed
# Task: STS12, Layer: 0 computed
# Task: STS12, Layer: 1 computed
# Task: STS12, Layer: 2 computed
# Task: STS12, Layer: 3 computed
# Task: STS12, Layer: 4 computed
# Task: STS12, Layer: 5 computed
# Task: STS12, Layer: 6 computed
# Task: STS12, Layer: 7 computed
# Task: STS12, Layer: 8 computed
# Task: STS12, Layer: 9 computed
# Task: STS12, Layer: 10 computed
# Task: STS12, Layer: 11 computed
# Task: STS12, Layer: 12 computed
# Task: STS12, Layer: 13 computed
# Task: STS12, Layer: 14 computed
# Task: STS12, Layer: 15 computed
# Task: STS12, Layer: 16 computed
# Task: STS12, Layer: 17 computed
# Task: STS12, Layer: 18 computed
# Task: STS12, Layer: 19 computed
# Task: STS12, Layer: 20 computed
# Task: STS12, Layer: 21 computed
# Task: STS12, Layer: 22 computed
# Task: STS12, Layer: 23 computed
# Task: STS12, Layer: 24 computed
# Task: STS12, Layer: 25 computed
# Task: STS12, Layer: 26 computed
# Task: STS12, Layer: 27 computed
# Task: STS12, Layer: 28 computed
# Task: STS12, Layer: 29 computed
# Task: STS12, Layer: 30 computed
# Task: STS12, Layer: 31 computed
# Task: STS12, Layer: 32 computed
# Task: STS13, Layer: 0 computed
# Task: STS13, Layer: 1 computed
# Task: STS13, Layer: 2 computed
# Task: STS13, Layer: 3 computed
# Task: STS13, Layer: 4 computed
# Task: STS13, Layer: 5 computed
# Task: STS13, Layer: 6 computed
# Task: STS13, Layer: 7 computed
# Task: STS13, Layer: 8 computed
# Task: STS13, Layer: 9 computed
# Task: STS13, Layer: 10 computed
# Task: STS13, Layer: 11 computed
# Task: STS13, Layer: 12 computed
# Task: STS13, Layer: 13 computed
# Task: STS13, Layer: 14 computed
# Task: STS13, Layer: 15 computed
# Task: STS13, Layer: 16 computed
# Task: STS13, Layer: 17 computed
# Task: STS13, Layer: 18 computed
# Task: STS13, Layer: 19 computed
# Task: STS13, Layer: 20 computed
# Task: STS13, Layer: 21 computed
# Task: STS13, Layer: 22 computed
# Task: STS13, Layer: 23 computed
# Task: STS13, Layer: 24 computed
# Task: STS13, Layer: 25 computed
# Task: STS13, Layer: 26 computed
# Task: STS13, Layer: 27 computed
# Task: STS13, Layer: 28 computed
# Task: STS13, Layer: 29 computed
# Task: STS13, Layer: 30 computed
# Task: STS13, Layer: 31 computed
# Task: STS13, Layer: 32 computed
# Task: STSBenchmark, Layer: 0 computed
# Task: STSBenchmark, Layer: 1 computed
# Task: STSBenchmark, Layer: 2 computed
# Task: STSBenchmark, Layer: 3 computed
# Task: STSBenchmark, Layer: 4 computed
# Task: STSBenchmark, Layer: 5 computed
# Task: STSBenchmark, Layer: 6 computed
# Task: STSBenchmark, Layer: 7 computed
# Task: STSBenchmark, Layer: 8 computed
# Task: STSBenchmark, Layer: 9 computed
# Task: STSBenchmark, Layer: 10 computed
# Task: STSBenchmark, Layer: 11 computed
# Task: STSBenchmark, Layer: 12 computed
# Task: STSBenchmark, Layer: 13 computed
# Task: STSBenchmark, Layer: 14 computed
# Task: STSBenchmark, Layer: 15 computed
# Task: STSBenchmark, Layer: 16 computed
# Task: STSBenchmark, Layer: 17 computed
# Task: STSBenchmark, Layer: 18 computed
# Task: STSBenchmark, Layer: 19 computed
# Task: STSBenchmark, Layer: 20 computed
# Task: STSBenchmark, Layer: 21 computed
# Task: STSBenchmark, Layer: 22 computed
# Task: STSBenchmark, Layer: 23 computed
# Task: STSBenchmark, Layer: 24 computed
# Task: STSBenchmark, Layer: 25 computed
# Task: STSBenchmark, Layer: 26 computed
# Task: STSBenchmark, Layer: 27 computed
# Task: STSBenchmark, Layer: 28 computed
# Task: STSBenchmark, Layer: 29 computed
# Task: STSBenchmark, Layer: 30 computed
# Task: STSBenchmark, Layer: 31 computed
# Task: STSBenchmark, Layer: 32 computed
# Task: STS17, Layer: 0 computed
# Task: STS17, Layer: 1 computed
# Task: STS17, Layer: 2 computed
# Task: STS17, Layer: 3 computed
# Task: STS17, Layer: 4 computed
# Task: STS17, Layer: 5 computed
# Task: STS17, Layer: 6 computed
# Task: STS17, Layer: 7 computed
# Task: STS17, Layer: 8 computed
# Task: STS17, Layer: 9 computed
# Task: STS17, Layer: 10 computed
# Task: STS17, Layer: 11 computed
# Task: STS17, Layer: 12 computed
# Task: STS17, Layer: 13 computed
# Task: STS17, Layer: 14 computed
# Task: STS17, Layer: 15 computed
# Task: STS17, Layer: 16 computed
# Task: STS17, Layer: 17 computed
# Task: STS17, Layer: 18 computed
# Task: STS17, Layer: 19 computed
# Task: STS17, Layer: 20 computed
# Task: STS17, Layer: 21 computed
# Task: STS17, Layer: 22 computed
# Task: STS17, Layer: 23 computed
# Task: STS17, Layer: 24 computed
# Task: STS17, Layer: 25 computed
# Task: STS17, Layer: 26 computed
# Task: STS17, Layer: 27 computed
# Task: STS17, Layer: 28 computed
# Task: STS17, Layer: 29 computed
# Task: STS17, Layer: 30 computed
# Task: STS17, Layer: 31 computed
# Task: STS17, Layer: 32 computed
# Task: STS15, Layer: 0 computed
# Task: STS15, Layer: 1 computed
# Task: STS15, Layer: 2 computed
# Task: STS15, Layer: 3 computed
# Task: STS15, Layer: 4 computed
# Task: STS15, Layer: 5 computed
# Task: STS15, Layer: 6 computed
# Task: STS15, Layer: 7 computed
# Task: STS15, Layer: 8 computed
# Task: STS15, Layer: 9 computed
# Task: STS15, Layer: 10 computed
# Task: STS15, Layer: 11 computed
# Task: STS15, Layer: 12 computed
# Task: STS15, Layer: 13 computed
# Task: STS15, Layer: 14 computed
# Task: STS15, Layer: 15 computed
# Task: STS15, Layer: 16 computed
# Task: STS15, Layer: 17 computed
# Task: STS15, Layer: 18 computed
# Task: STS15, Layer: 19 computed
# Task: STS15, Layer: 20 computed
# Task: STS15, Layer: 21 computed
# Task: STS15, Layer: 22 computed
# Task: STS15, Layer: 23 computed
# Task: STS15, Layer: 24 computed
# Task: STS15, Layer: 25 computed
# Task: STS15, Layer: 26 computed
# Task: STS15, Layer: 27 computed
# Task: STS15, Layer: 28 computed
# Task: STS15, Layer: 29 computed
# Task: STS15, Layer: 30 computed
# Task: STS15, Layer: 31 computed
# Task: STS15, Layer: 32 computed
# Task: STS16, Layer: 0 computed
# Task: STS16, Layer: 1 computed
# Task: STS16, Layer: 2 computed
# Task: STS16, Layer: 3 computed
# Task: STS16, Layer: 4 computed
# Task: STS16, Layer: 5 computed
# Task: STS16, Layer: 6 computed
# Task: STS16, Layer: 7 computed
# Task: STS16, Layer: 8 computed
# Task: STS16, Layer: 9 computed
# Task: STS16, Layer: 10 computed
# Task: STS16, Layer: 11 computed
# Task: STS16, Layer: 12 computed
# Task: STS16, Layer: 13 computed
# Task: STS16, Layer: 14 computed
# Task: STS16, Layer: 15 computed
# Task: STS16, Layer: 16 computed
# Task: STS16, Layer: 17 computed
# Task: STS16, Layer: 18 computed
# Task: STS16, Layer: 19 computed
# Task: STS16, Layer: 20 computed
# Task: STS16, Layer: 21 computed
# Task: STS16, Layer: 22 computed
# Task: STS16, Layer: 23 computed
# Task: STS16, Layer: 24 computed
# Task: STS16, Layer: 25 computed
# Task: STS16, Layer: 26 computed
# Task: STS16, Layer: 27 computed
# Task: STS16, Layer: 28 computed
# Task: STS16, Layer: 29 computed
# Task: STS16, Layer: 30 computed
# Task: STS16, Layer: 31 computed
# Task: STS16, Layer: 32 computed
# Task: BIOSSES, Layer: 0 computed
# Task: BIOSSES, Layer: 1 computed
# Task: BIOSSES, Layer: 2 computed
# Task: BIOSSES, Layer: 3 computed
# Task: BIOSSES, Layer: 4 computed
# Task: BIOSSES, Layer: 5 computed
# Task: BIOSSES, Layer: 6 computed
# Task: BIOSSES, Layer: 7 computed
# Task: BIOSSES, Layer: 8 computed
# Task: BIOSSES, Layer: 9 computed
# Task: BIOSSES, Layer: 10 computed
# Task: BIOSSES, Layer: 11 computed
# Task: BIOSSES, Layer: 12 computed
# Task: BIOSSES, Layer: 13 computed
# Task: BIOSSES, Layer: 14 computed
# Task: BIOSSES, Layer: 15 computed
# Task: BIOSSES, Layer: 16 computed
# Task: BIOSSES, Layer: 17 computed
# Task: BIOSSES, Layer: 18 computed
# Task: BIOSSES, Layer: 19 computed
# Task: BIOSSES, Layer: 20 computed
# Task: BIOSSES, Layer: 21 computed
# Task: BIOSSES, Layer: 22 computed
# Task: BIOSSES, Layer: 23 computed
# Task: BIOSSES, Layer: 24 computed
# Task: BIOSSES, Layer: 25 computed
# Task: BIOSSES, Layer: 26 computed
# Task: BIOSSES, Layer: 27 computed
# Task: BIOSSES, Layer: 28 computed
# Task: BIOSSES, Layer: 29 computed
# Task: BIOSSES, Layer: 30 computed
# Task: BIOSSES, Layer: 31 computed
# Task: BIOSSES, Layer: 32 computed
# Task: BIOSSES, Layer: 33 computed
# Task: BIOSSES, Layer: 34 computed
# Task: BIOSSES, Layer: 35 computed
# Task: BIOSSES, Layer: 36 computed
# Task: STS14, Layer: 0 computed
# Task: STS14, Layer: 1 computed
# Task: STS14, Layer: 2 computed
# Task: STS14, Layer: 3 computed
# Task: STS14, Layer: 4 computed
# Task: STS14, Layer: 5 computed
# Task: STS14, Layer: 6 computed
# Task: STS14, Layer: 7 computed
# Task: STS14, Layer: 8 computed
# Task: STS14, Layer: 9 computed
# Task: STS14, Layer: 10 computed
# Task: STS14, Layer: 11 computed
# Task: STS14, Layer: 12 computed
# Task: STS14, Layer: 13 computed
# Task: STS14, Layer: 14 computed
# Task: STS14, Layer: 15 computed
# Task: STS14, Layer: 16 computed
# Task: STS14, Layer: 17 computed
# Task: STS14, Layer: 18 computed
# Task: STS14, Layer: 19 computed
# Task: STS14, Layer: 20 computed
# Task: STS14, Layer: 21 computed
# Task: STS14, Layer: 22 computed
# Task: STS14, Layer: 23 computed
# Task: STS14, Layer: 24 computed
# Task: STS14, Layer: 25 computed
# Task: STS14, Layer: 26 computed
# Task: STS14, Layer: 27 computed
# Task: STS14, Layer: 28 computed
# Task: STS14, Layer: 29 computed
# Task: STS14, Layer: 30 computed
# Task: STS14, Layer: 31 computed
# Task: STS14, Layer: 32 computed
# Task: SICK-R, Layer: 0 computed
# Task: SICK-R, Layer: 1 computed
# Task: SICK-R, Layer: 2 computed
# Task: SICK-R, Layer: 3 computed
# Task: SICK-R, Layer: 4 computed
# Task: SICK-R, Layer: 5 computed
# Task: SICK-R, Layer: 6 computed
# Task: SICK-R, Layer: 7 computed
# Task: SICK-R, Layer: 8 computed
# Task: SICK-R, Layer: 9 computed
# Task: SICK-R, Layer: 10 computed
# Task: SICK-R, Layer: 11 computed
# Task: SICK-R, Layer: 12 computed
# Task: SICK-R, Layer: 13 computed
# Task: SICK-R, Layer: 14 computed
# Task: SICK-R, Layer: 15 computed
# Task: SICK-R, Layer: 16 computed
# Task: SICK-R, Layer: 17 computed
# Task: SICK-R, Layer: 18 computed
# Task: SICK-R, Layer: 19 computed
# Task: SICK-R, Layer: 20 computed
# Task: SICK-R, Layer: 21 computed
# Task: SICK-R, Layer: 22 computed
# Task: SICK-R, Layer: 23 computed
# Task: SICK-R, Layer: 24 computed
# Task: SICK-R, Layer: 25 computed
# Task: SICK-R, Layer: 26 computed
# Task: SICK-R, Layer: 27 computed
# Task: SICK-R, Layer: 28 computed
# Task: SICK-R, Layer: 29 computed
# Task: SICK-R, Layer: 30 computed
# Task: SICK-R, Layer: 31 computed
# Task: SICK-R, Layer: 32 computed
# Task: SprintDuplicateQuestions, Layer: 0 computed
# Task: SprintDuplicateQuestions, Layer: 1 computed
# Task: SprintDuplicateQuestions, Layer: 2 computed
# Task: SprintDuplicateQuestions, Layer: 3 computed
# Task: SprintDuplicateQuestions, Layer: 4 computed
# Task: SprintDuplicateQuestions, Layer: 5 computed
# Task: SprintDuplicateQuestions, Layer: 6 computed
# Task: SprintDuplicateQuestions, Layer: 7 computed
# Task: SprintDuplicateQuestions, Layer: 8 computed
# Task: SprintDuplicateQuestions, Layer: 9 computed
# Task: SprintDuplicateQuestions, Layer: 10 computed
# Task: SprintDuplicateQuestions, Layer: 11 computed
# Task: SprintDuplicateQuestions, Layer: 12 computed
# Task: SprintDuplicateQuestions, Layer: 13 computed
# Task: SprintDuplicateQuestions, Layer: 14 computed
# Task: SprintDuplicateQuestions, Layer: 15 computed
# Task: SprintDuplicateQuestions, Layer: 16 computed
# Task: SprintDuplicateQuestions, Layer: 17 computed
# Task: SprintDuplicateQuestions, Layer: 18 computed
# Task: SprintDuplicateQuestions, Layer: 19 computed
# Task: SprintDuplicateQuestions, Layer: 20 computed
# Task: SprintDuplicateQuestions, Layer: 21 computed
# Task: SprintDuplicateQuestions, Layer: 22 computed
# Task: SprintDuplicateQuestions, Layer: 23 computed
# Task: SprintDuplicateQuestions, Layer: 24 computed
# Task: SprintDuplicateQuestions, Layer: 25 computed
# Task: SprintDuplicateQuestions, Layer: 26 computed
# Task: SprintDuplicateQuestions, Layer: 27 computed
# Task: SprintDuplicateQuestions, Layer: 28 computed
# Task: SprintDuplicateQuestions, Layer: 29 computed
# Task: SprintDuplicateQuestions, Layer: 30 computed
# Task: SprintDuplicateQuestions, Layer: 31 computed
# Task: SprintDuplicateQuestions, Layer: 32 computed
# Task: TwitterURLCorpus, Layer: 0 computed
# Task: TwitterURLCorpus, Layer: 1 computed
# Task: TwitterURLCorpus, Layer: 2 computed
# Task: TwitterURLCorpus, Layer: 3 computed
# Task: TwitterURLCorpus, Layer: 4 computed
# Task: TwitterURLCorpus, Layer: 5 computed
# Task: TwitterURLCorpus, Layer: 6 computed
# Task: TwitterURLCorpus, Layer: 7 computed
# Task: TwitterURLCorpus, Layer: 8 computed
# Task: TwitterURLCorpus, Layer: 9 computed
# Task: TwitterURLCorpus, Layer: 10 computed
# Task: TwitterURLCorpus, Layer: 11 computed
# Task: TwitterURLCorpus, Layer: 12 computed
# Task: TwitterURLCorpus, Layer: 13 computed
# Task: TwitterURLCorpus, Layer: 14 computed
# Task: TwitterURLCorpus, Layer: 15 computed
# Task: TwitterURLCorpus, Layer: 16 computed
# Task: TwitterURLCorpus, Layer: 17 computed
# Task: TwitterURLCorpus, Layer: 18 computed
# Task: TwitterURLCorpus, Layer: 19 computed
# Task: TwitterURLCorpus, Layer: 20 computed
# Task: TwitterURLCorpus, Layer: 21 computed
# Task: TwitterURLCorpus, Layer: 22 computed
# Task: TwitterURLCorpus, Layer: 23 computed
# Task: TwitterURLCorpus, Layer: 24 computed
# Task: TwitterURLCorpus, Layer: 25 computed
# Task: TwitterURLCorpus, Layer: 26 computed
# Task: TwitterURLCorpus, Layer: 27 computed
# Task: TwitterURLCorpus, Layer: 28 computed
# Task: TwitterSemEval2015, Layer: 0 computed
# Task: TwitterSemEval2015, Layer: 1 computed
# Task: TwitterSemEval2015, Layer: 2 computed
# Task: TwitterSemEval2015, Layer: 3 computed
# Task: TwitterSemEval2015, Layer: 4 computed
# Task: TwitterSemEval2015, Layer: 5 computed
# Task: TwitterSemEval2015, Layer: 6 computed
# Task: TwitterSemEval2015, Layer: 7 computed
# Task: TwitterSemEval2015, Layer: 8 computed
# Task: TwitterSemEval2015, Layer: 9 computed
# Task: TwitterSemEval2015, Layer: 10 computed
# Task: TwitterSemEval2015, Layer: 11 computed
# Task: TwitterSemEval2015, Layer: 12 computed
# Task: TwitterSemEval2015, Layer: 13 computed
# Task: TwitterSemEval2015, Layer: 14 computed
# Task: TwitterSemEval2015, Layer: 15 computed
# Task: TwitterSemEval2015, Layer: 16 computed
# Task: TwitterSemEval2015, Layer: 17 computed
# Task: TwitterSemEval2015, Layer: 18 computed
# Task: TwitterSemEval2015, Layer: 19 computed
# Task: TwitterSemEval2015, Layer: 20 computed
# Task: TwitterSemEval2015, Layer: 21 computed
# Task: TwitterSemEval2015, Layer: 22 computed
# Task: TwitterSemEval2015, Layer: 23 computed
# Task: TwitterSemEval2015, Layer: 24 computed
# Task: TwitterSemEval2015, Layer: 25 computed
# Task: TwitterSemEval2015, Layer: 26 computed
# Task: TwitterSemEval2015, Layer: 27 computed
# Task: TwitterSemEval2015, Layer: 28 computed
# Task: TwitterSemEval2015, Layer: 29 computed
# Task: TwitterSemEval2015, Layer: 30 computed
# Task: TwitterSemEval2015, Layer: 31 computed
# Task: TwitterSemEval2015, Layer: 32 computed

# %%
# find number of tasks where the best performance is not the last layer

# Initialize counters
total_tasks = 0
tasks_with_best_not_last = 0

best_accs = []
last_layer_accs = []

# Iterate through all tasks
for task_type, tasks in task_types.items():
    for task, data in tasks.items():
        total_tasks += 1
        scores = data['scores']
        
        # Check if the best performance is not in the last layer
        if np.argmax(scores) != len(scores) - 1:
            tasks_with_best_not_last += 1

        best_accs.append(np.max(scores))
        last_layer_accs.append(scores[-1])

print(best_accs)
print(last_layer_accs)

print(np.mean(best_accs))
print(np.mean(last_layer_accs))

# Calculate the percentage
percentage = (tasks_with_best_not_last / total_tasks) * 100

print(f"Total number of tasks: {total_tasks}")
print(f"Number of tasks where the best performance is not in the last layer: {tasks_with_best_not_last}")
print(f"Percentage: {percentage:.2f}%")
# Out:
# [0.4785367312702702, 0.6218379466318121, 0.29355907275180054, 0.3650855037471309, 0.6927272727272726, 0.8269721842225263, 0.3407, 0.7115139078887369, 0.36557999999999996, 0.5867182246133155, 0.8144720177224821, 0.6073974445191661, 0.675, 0.5326259196378043, 0.4080739667406755, 0.22646350512382202, 0.25243578659803134, 0.2498636777121003, 0.2371181579947473, 0.29649848020104647, 0.39374721525950906, 0.5492820018176146, 0.4845246369445395, 0.6261900540269817, 0.5880916583248845, 0.556085397618513, 0.6525931830313918, 0.4518453446399665, 0.5509916491470325, 0.5599188561497144, 0.7655541907752994, 0.5511181947565569]
# [0.4666739012872454, 0.5404835553792048, 0.29174166717009997, 0.33714052878552137, 0.6080194805194805, 0.770360237118103, 0.30465, 0.6800729594163246, 0.35117999999999994, 0.5580699394754539, 0.7621317326411421, 0.5758238063214527, 0.652978515625, 0.523712507074137, 0.3828942863157288, 0.21870382170413888, 0.20658919099646292, 0.2153524826814456, 0.21295986711528817, 0.24637200643554583, 0.3331711519157323, 0.5160168785599357, 0.42077245336834024, 0.55665617750667, 0.5550895580439066, 0.548119432994297, 0.5961340652467912, 0.42827366313663995, 0.5048103193165425, 0.36463107891842717, 0.7535565583234608, 0.529957834925171]
# 0.5097850682060857
# 0.4691593643224278
# Total number of tasks: 32
# Number of tasks where the best performance is not in the last layer: 32
# Percentage: 100.00%

# %% [markdown]
# # All models - Avg Score per layer per task type

# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# Define model families and sizes
model_families = ['Pythia', 'mamba']  # Add or modify as needed
model_sizes = {
    'Pythia': ['14m', '70m', '160m', '410m'],
    'mamba': ['130m']
}

results = {}

# Load results for each model family and size
for family in model_families:
    results[family] = {}
    for size in model_sizes[family]:
        results[family][size] = load_layerwise_results_for_specific_model(ModelSpecifications(family, size, revision=revision))

# Group tasks by task type
task_types = {}
for family in model_families:
    for size in model_sizes[family]:
        for task, data in results[family][size]['mteb'].items():
            task_type = data['task_type']
            if task_type not in task_types:
                task_types[task_type] = {}
            if task not in task_types[task_type]:
                task_types[task_type][task] = {}
            if family not in task_types[task_type][task]:
                task_types[task_type][task][family] = {}
            task_types[task_type][task][family][size] = data

# Create subplots
num_task_types = len(task_types)
fig, axs = plt.subplots(1, num_task_types, figsize=(4*num_task_types, 4), sharey=True)

for i, (task_type, tasks) in enumerate(task_types.items()):
    ax = axs[i] if num_task_types > 1 else axs
    
    for family in model_families:
        for size in model_sizes[family]:
            all_scores = []
            max_layers = 0
            for task, family_data in tasks.items():
                if family in family_data and size in family_data[family]:
                    scores = family_data[family][size]['scores']
                    max_layers = max(max_layers, len(scores))
                    all_scores.append(scores)
            
            # Calculate and plot the average line and points for each size
            if all_scores:
                average_scores = np.mean(all_scores, axis=0)
                layers_percentage = np.linspace(0, 100, len(average_scores))
                linestyle = '--' if family == 'mamba' else '-'
                ax.plot(layers_percentage, average_scores, linewidth=2, linestyle=linestyle, label=f'{family} {size}')
                ax.scatter(layers_percentage, average_scores, s=20)
    ax.set_xlabel('Layer Depth (%)')
    if i == 0:
        ax.set_ylabel('Average Score')
        ax.legend()
    ax.set_title(f'Avg. {task_type} Performance')
       
    ax.grid(True)
    ax.set_xlim(0, 100)

plt.tight_layout()
plt.show()

# %% [markdown]
# # One Model - Metrics per layer per task dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

model_family = 'Pythia'
model_size = '14m'
revision = 'main'

PLOT_INDIVIDUAL_TASKS = True
PLOT_WIKITEXT = False

model_specs = ModelSpecifications(model_family, model_size, revision=revision)
results = load_layerwise_results_for_specific_model(model_specs)

# Group tasks by task type
task_types = {}
metrics = set()
wikitext_data = None
for task, data in results['metrics'].items():
    if task == 'wikitext':
        wikitext_data = data
        continue
    else:
        dataset_name = '/'.join(task.split('/')[0:2])
        # find the task with the same dataset name in the mteb results
        for mteb_task, mteb_data in results['mteb'].items():
            mteb_dataset_name = get_dataset_name_from_task_name(mteb_task)
            if mteb_dataset_name == dataset_name:
                task_type = mteb_data['task_type']
                break
    
    if task_type not in task_types:
        task_types[task_type] = {}
    task_types[task_type][task] = data
    metrics.update(data.keys())

# Remove curvature metric for now
metrics = {metric for metric in metrics if metric != 'curvature'}

# Create subplots
num_task_types = len(task_types)
num_metrics = len(metrics)
fig, axs = plt.subplots(num_metrics, num_task_types, figsize=(4*num_task_types, 4*num_metrics), sharex=True, sharey='row')

for i, metric in enumerate(metrics):
    for j, (task_type, tasks) in enumerate(task_types.items()):
        ax = axs[i, j] if num_metrics > 1 and num_task_types > 1 else axs[i] if num_metrics > 1 else axs[j] if num_task_types > 1 else axs
        all_metric_values = []
        if PLOT_INDIVIDUAL_TASKS:
            for task, data in tasks.items():
                if metric in data.keys():
                    metric_values = data[metric]
                    normalization_type = 'maxEntropy' if 'maxEntropy' in metric_values.keys() else 'raw'
                    metric_values = metric_values[normalization_type]
                    
                    layers = range(len(metric_values))
                    ax.plot(layers, metric_values, alpha=0.7, marker='x')
                    all_metric_values.append(metric_values)
        else:
            for task, data in tasks.items():
                if metric in data.keys():
                    metric_values = data[metric]
                    normalization_type = 'maxEntropy' if 'maxEntropy' in metric_values.keys() else 'raw'
                    metric_values = metric_values[normalization_type]
                    all_metric_values.append(metric_values)
        
        # Add wikitext data to every subplot if PLOT_WIKITEXT is True
        if PLOT_WIKITEXT and wikitext_data and metric in wikitext_data.keys():
            wikitext_values = wikitext_data[metric]
            normalization_type = 'maxEntropy' if 'maxEntropy' in wikitext_values.keys() else 'raw'
            wikitext_values = wikitext_values[normalization_type]
            ax.plot(layers, wikitext_values, label='wikitext', linestyle='--', color='red', linewidth=2, marker='x')
        
        # Calculate and plot the average line with standard deviation
        if all_metric_values:
            average_values = np.mean(all_metric_values, axis=0)
            std_values = np.std(all_metric_values, axis=0)
            ax.plot(layers, average_values, label='Average', linewidth=3, color='black', marker='x')
            ax.fill_between(layers, average_values - std_values, average_values + std_values, alpha=0.4, color='gray')
        ax.grid(True)

        # Only set the y-label for the leftmost subplot in each row
        if j == 0:
            ax.set_ylabel(metric, fontsize=14, fontweight='bold')
        
        # Only set the x-label for the bottom subplot in each column
        if i == num_metrics - 1:
            ax.set_xlabel('Layer')
        
        if i == 0 and j == 0:
            ax.legend()

# Add task type labels on top of each column
for j, task_type in enumerate(task_types.keys()):
    fig.text((j + 0.5) / num_task_types, 0.98, task_type, ha='center', va='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.subplots_adjust(top=0.95)  # Adjust top margin to accommodate task type labels
plt.show()

# %% [markdown]
# # One Model - Average task type metrics plotted together

# %%
import matplotlib.pyplot as plt
import numpy as np

model_family = 'Pythia'
model_size = '14m'
revision = 'main'

model_specs = ModelSpecifications(model_family, model_size, revision=revision)
results = load_layerwise_results_for_specific_model(model_specs)

# Group tasks by task type
task_types = {}
metrics = set()
wikitext_data = None
for task, data in results['metrics'].items():
    if task == 'wikitext':
        wikitext_data = data
        continue
    else:
        dataset_name = '/'.join(task.split('/')[0:2])
        # find the task with the same dataset name in the mteb results
        for mteb_task, mteb_data in results['mteb'].items():
            mteb_dataset_name = get_dataset_name_from_task_name(mteb_task)
            if mteb_dataset_name == dataset_name:
                task_type = mteb_data['task_type']
                break
    
    if task_type not in task_types:
        task_types[task_type] = {}
    task_types[task_type][task] = data
    metrics.update(data.keys())

# Remove curvature metric for now
metrics = {metric for metric in metrics if metric != 'curvature'}

# Create subplots
num_metrics = len(metrics)
fig, axs = plt.subplots(1, num_metrics, figsize=(4*num_metrics, 5), sharey=False)

colors = plt.cm.rainbow(np.linspace(0, 1, len(task_types)))
task_type_colors = dict(zip(task_types.keys(), colors))

PLOT_WIKITEXT = False

for i, metric in enumerate(metrics):
    ax = axs[i] if num_metrics > 1 else axs
    
    for task_type, tasks in task_types.items():
        all_metric_values = []
        for task, data in tasks.items():
            if metric in data.keys():
                metric_values = data[metric]
                normalization_type = 'maxEntropy' if 'maxEntropy' in metric_values.keys() else 'raw'
                metric_values = metric_values[normalization_type]
                all_metric_values.append(metric_values)
        
        # Calculate and plot the average line with standard deviation
        if all_metric_values:
            average_values = np.mean(all_metric_values, axis=0)
            std_values = np.std(all_metric_values, axis=0)
            ax.plot(layers, average_values, label=task_type, linewidth=2, color=task_type_colors[task_type], marker='o')
            ax.fill_between(layers, average_values - std_values, average_values + std_values, alpha=0.2, color=task_type_colors[task_type])
    
    # Add wikitext data to every subplot if plot_wikitext is True
    if PLOT_WIKITEXT and wikitext_data and metric in wikitext_data.keys():
        wikitext_values = wikitext_data[metric]
        normalization_type = 'maxEntropy' if 'maxEntropy' in wikitext_values.keys() else 'raw'
        wikitext_values = wikitext_values[normalization_type]
        ax.plot(layers, wikitext_values, label='wikitext', linestyle='--', color='red', linewidth=2, marker='x')
    
    ax.grid(True)
    ax.set_xlabel('Layer')
    ax.set_title(f'{metric}', fontsize=16, fontweight='bold')
    
    # Only set the y-label for the leftmost subplot
    if i == 0:
        ax.set_ylabel('Value', fontsize=14, fontweight='bold')
    
    # Only show the legend for the rightmost subplot
    if i == num_metrics - 1:
        ax.legend(title='Task Types', title_fontsize='13', fontsize='11', loc='upper left')

plt.suptitle(f'Metrics across Task Types for {model_family} {model_size}', fontsize=18, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # All Models - Comparison against different task types

# %%
model_families = ['Pythia', 'mamba']  # Add or modify as needed
model_sizes = {
    'Pythia': ['14m', '70m', '160m', '410m'],
    'mamba': ['130m']
}

USE_DEPTH_PERCENTAGE = True
USE_WIKITEXT = False

results = {}

# Load results for all models
for model_family in model_families:
    for model_size in model_sizes[model_family]:
        revision = 'main'
        model_specs = ModelSpecifications(model_family, model_size, revision=revision)
        results[(model_family, model_size)] = load_layerwise_results_for_specific_model(model_specs)

# Group tasks by task type
task_types = {}
metrics = set()
wikitext_data = {}
for (model_family, model_size), model_results in results.items():
    for task, data in model_results['metrics'].items():
        if task == 'wikitext':
            wikitext_data[(model_family, model_size)] = data
            continue
        else:
            dataset_name = '/'.join(task.split('/')[0:2])
            # find the task with the same dataset name in the mteb results
            for mteb_task, mteb_data in model_results['mteb'].items():
                mteb_dataset_name = get_dataset_name_from_task_name(mteb_task)
                if mteb_dataset_name == dataset_name:
                    task_type = mteb_data['task_type']
                    break
        
        if task_type not in task_types:
            task_types[task_type] = {}
        if (model_family, model_size) not in task_types[task_type]:
            task_types[task_type][(model_family, model_size)] = {}
        task_types[task_type][(model_family, model_size)][task] = data
        metrics.update(data.keys())

# Remove curvature metric for now
metrics = {metric for metric in metrics if metric != 'curvature'}

# Create subplots
num_metrics = len(metrics)
num_task_types = len(task_types)
fig, axs = plt.subplots(num_metrics, num_task_types, figsize=(3.5*num_task_types, 3.5*num_metrics))

PLOT_WIKITEXT = False

for i, metric in enumerate(metrics):
    for j, (task_type, models) in enumerate(task_types.items()):
        ax = axs[i, j] if num_metrics > 1 and num_task_types > 1 else axs[i] if num_task_types == 1 else axs[j] if num_metrics == 1 else axs
        
        for (model_family, model_size), tasks in models.items():
            all_metric_values = []
            for task, data in tasks.items():
                if metric in data.keys():
                    metric_values = data[metric]
                    normalization_type = 'maxEntropy' if 'maxEntropy' in metric_values.keys() else 'raw'
                    metric_values = metric_values[normalization_type]
                    all_metric_values.append(metric_values)
            
            # Calculate and plot the average line with standard deviation
            if all_metric_values:
                num_layers = len(all_metric_values[0])
                depth_percentage = np.linspace(0, 100, num_layers)
                average_values = np.mean(all_metric_values, axis=0)
                std_values = np.std(all_metric_values, axis=0)
                line, = ax.plot(depth_percentage, average_values, label=f'{model_family} {model_size}', linewidth=2, marker='o')
                ax.fill_between(depth_percentage, average_values - std_values, average_values + std_values, alpha=0.2, color=line.get_color())
        
        # Add wikitext data to every subplot if plot_wikitext is True
        if PLOT_WIKITEXT:
            for (model_family, model_size), data in wikitext_data.items():
                if metric in data.keys():
                    wikitext_values = data[metric]
                    normalization_type = 'maxEntropy' if 'maxEntropy' in wikitext_values.keys() else 'raw'
                    wikitext_values = wikitext_values[normalization_type]
                    num_layers = len(wikitext_values)
                    depth_percentage = np.linspace(0, 100, num_layers)
                    ax.plot(depth_percentage, wikitext_values, label=f'{model_family} {model_size} (wikitext)', linestyle='--', linewidth=2, marker='x')
        
        ax.grid(True)
        ax.set_xlabel('Depth (%)')
       # Only set the y-label for the leftmost subplot in each row
        if j == 0:
            ax.set_ylabel(metric, fontsize=14, fontweight='bold')
        
        if i == 0 and j == 0:
            ax.legend()

# Add task type labels on top of each column
for j, task_type in enumerate(task_types.keys()):
    fig.text((j + 0.5) / num_task_types, 0.98, task_type, ha='center', va='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.subplots_adjust(top=0.95)  # Adjust top margin to accommodate task type labels
plt.show()

# %% [markdown]
# # All Models - Compute Correlations between Metrics and performance

# %%
#model_families = ['Pythia', 'mamba']  # Add or modify as needed
# model_sizes = {
#     'Pythia': ['14m', '70m', '160m', '410m'],
#     'mamba': ['130m']
# }

model_families = ['Pythia']  # Add or modify as needed
model_sizes = {
    'Pythia': ['410m'],
    'mamba': ['130m']
}

USE_DEPTH_PERCENTAGE = True
USE_WIKITEXT = False

results = {}

# Load results for all models
for model_family in model_families:
    for model_size in model_sizes[model_family]:
        revision = 'main'
        model_specs = ModelSpecifications(model_family, model_size, revision=revision)
        results[(model_family, model_size)] = load_layerwise_results_for_specific_model(model_specs)

# Group tasks by task type
task_types = {}
metrics = set()
wikitext_data = {}
for (model_family, model_size), model_results in results.items():
    for task, data in model_results['metrics'].items():
        if task == 'wikitext':
            continue
        else:
            dataset_name = '/'.join(task.split('/')[0:2])
            # find the task with the same dataset name in the mteb results
            for mteb_task, mteb_data in model_results['mteb'].items():
                mteb_dataset_name = get_dataset_name_from_task_name(mteb_task)
                if mteb_dataset_name == dataset_name:
                    task_type = mteb_data['task_type']
                    break
        
        if task_type not in task_types:
            task_types[task_type] = {}
        if (model_family, model_size) not in task_types[task_type]:
            task_types[task_type][(model_family, model_size)] = {}
        task_types[task_type][(model_family, model_size)][task] = data
        metrics.update(data.keys())

# Remove curvature metric for now
metrics = {metric for metric in metrics if metric != 'curvature'}

# %%
from scipy.stats import spearmanr

# Initialize a dictionary to store metric-score pairs for each dataset
metric_score_pairs = {}

# Iterate through each model's results
for (model_family, model_size), model_results in results.items():
    for dataset, dataset_data in model_results['metrics'].items():
        if dataset == 'wikitext':
            continue
            
        # Map dataset name to task name
        task_name = None
        dataset_name = '/'.join(dataset.split('/')[0:2])
        for mteb_task, mteb_data in model_results['mteb'].items():
            if get_dataset_name_from_task_name(mteb_task) == dataset_name:
                task_name = mteb_task
                break
        
        if task_name is None:
            print(f"Warning: No matching task found for dataset {dataset}")
            continue
        
        GET_ALL_PAIRS = True

        if not GET_ALL_PAIRS:
            # Get the performance data for this dataset
            performance = model_results['mteb'][task_name]['scores'][-1]
        
            # Iterate through each metric
            for metric in metrics:
                if metric in dataset_data:
                    metric_values = dataset_data[metric]
                    normalization_type = 'raw' if 'maxEntropy' in metric_values.keys() else 'raw'
                    metric_values = metric_values[normalization_type]

                    last_layer_score = metric_values[-1]
                    
                    if metric not in metric_score_pairs:
                        metric_score_pairs[metric] = []
                    
                    # Append the (metric score, performance) pair
                    metric_score_pairs[metric].append((last_layer_score, performance))
        else:
            performance = model_results['mteb'][task_name]['scores']
            # Get all pairs
            for metric in metrics:
                if metric in dataset_data:
                    metric_values = dataset_data[metric]
                    normalization_type = 'raw' if 'maxEntropy' in metric_values.keys() else 'raw'
                    metric_values = metric_values[normalization_type]
                    
                    for idx in range(len(metric_values)):
                        if idx not in metric_score_pairs:
                            metric_score_pairs[idx] = {}
                        if metric not in metric_score_pairs[idx]:
                            metric_score_pairs[idx][metric] = []
                        # Append the (metric score, performance) pair
                        metric_score_pairs[idx][metric].append((metric_values[idx], performance[idx]))

if GET_ALL_PAIRS:
    correlation_matrix = {}
    for layer_idx, layer_data in metric_score_pairs.items():
        if layer_idx not in correlation_matrix:
            correlation_matrix[layer_idx] = {}

        for metric, pairs in layer_data.items():
            if metric not in correlation_matrix[layer_idx]:
                correlation_matrix[layer_idx][metric] = []

            x = [pair[0] for pair in pairs]
            y = [pair[1] for pair in pairs]
            correlation_matrix[layer_idx][metric], _ = spearmanr(x, y)
else:
    # Compute Spearman correlation coefficient for each metric-dataset pair
    correlation_matrix = {}
    for metric, pairs in metric_score_pairs.items():
        x = [pair[0] for pair in pairs]
        y = [pair[1] for pair in pairs]
        correlation_matrix[metric], _ = spearmanr(x, y)

# %%
(entropy, performance)_task

# %%
if GET_ALL_PAIRS:
    for layer_idx, layer_data in correlation_matrix.items():
        if layer_idx == len(correlation_matrix) - 1:
            print(f"Layer {layer_idx}:")
            for metric, correlation in layer_data.items():
                print(f"  {metric}: {correlation:.4f}")
else:
    for metric, correlation in correlation_matrix.items():
        print(f"{metric}: {correlation:.4f}")
# Out:
# Layer 24:
#   dime: 0.6203
#   infonce: -0.2571
#   entropy_dataset: 0.2338
#   entropy_sentence: -0.1115
#   lidar: -0.3401

# %%
# Extract InfoNCE and performance data
infonce_scores = [pair[0] for pair in metric_score_pairs['infonce']]
performance_scores = [pair[1] for pair in metric_score_pairs['infonce']]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(infonce_scores, performance_scores, alpha=0.6)
plt.xlabel('InfoNCE Score')
plt.ylabel('Performance')
plt.title('InfoNCE vs Performance')

# Add a trend line
z = np.polyfit(infonce_scores, performance_scores, 1)
p = np.poly1d(z)
plt.plot(infonce_scores, p(infonce_scores), "r--", alpha=0.8)

# Add correlation coefficient to the plot
correlation, _ = spearmanr(infonce_scores, performance_scores)
plt.text(0.05, 0.95, f'Spearman correlation: {correlation:.4f}', 
         transform=plt.gca().transAxes, verticalalignment='top')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[199], line 2
#       1 # Extract InfoNCE and performance data
# ----> 2 infonce_scores = [pair[0] for pair in metric_score_pairs['infonce']]
#       3 performance_scores = [pair[1] for pair in metric_score_pairs['infonce']]
#       5 # Create the scatter plot
#
# KeyError: 'infonce'
